# %%
import pandas as pd

# Assuming your CSV file is named 'data.csv' and is in the same directory
df = pd.read_csv('./amazon_co-ecommerce_sample.csv')

# To view the first few rows of the DataFrame
print(df.head())
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock number_of_reviews  number_of_answered_questions  \
# 0                     5 new                15                           1.0
# 1                       NaN                 2                           1.0
# ...

# %%
print(df.columns)
# Out:
# Index(['uniq_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'product_information', 'product_description',
#        'items_customers_buy_after_viewing_this_item',
#        'customer_questions_and_answers', 'customer_reviews', 'sellers'],
#       dtype='object')

# %%
selected_cols = df[['product_name', 'number_of_reviews', 'uniq_id']]
selected_cols.head(50)
# Out:
#                                          product_name number_of_reviews  \
# 0                               Hornby 2014 Catalogue                15
# 1   FunkyBuys® Large Christmas Holiday Express Fes...                 2
# 2   CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...                17
# 3      HORNBY Coach R4410A BR Hawksworth Corridor 3rd                 1
# 4   Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...                 3
# 5   20pcs Model Garden Light Double Heads Lamppost...                 2
# 6   Hornby 00 Gauge 230mm BR Bogie Passenger Brake...                 2
# 7                    Hornby Santa's Express Train Set                36
# 8   Hornby Gauge Western Express Digital Train Set...                 1
# 9   Learning Curve Chuggington Interactive Chatsworth                 8
# 10  Hornby Gauge Railroad Mosley Tarmacadam Locomo...                 1
# 11  Kato (USA) 176-1308 F3B Denver & Rio Grande We...                 1
# ...

# %%
import pandas as pd
import gzip
import json

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield json.loads(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

df = getDF('blah.gz')

# %%
df.head(30)
# Out:
#     overall  verified   reviewTime      reviewerID        asin  \
# 0       5.0      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1       2.0      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2       4.0     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3       2.0      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4       3.0     False  07 27, 2014   A89F3LQADZBS5  7106116521
# 5       5.0      True  07 19, 2014  A29HLOUW0NS0EH  7106116521
# 6       4.0      True  05 31, 2014   A7QS961ROI6E0  7106116521
# 7       3.0      True  09 22, 2013  A1BB77SEBQT8VX  B00007GDFV
# 8       3.0      True  07 17, 2013   AHWOW7D1ABO9C  B00007GDFV
# 9       3.0      True  04 13, 2013   AKS3GULZE0HFC  B00007GDFV
# 10      4.0      True   03 9, 2013   A38NS6NF6WPXS  B00007GDFV
# 11      2.0      True  01 27, 2013  A1KOKO3HTSAI1H  B00007GDFV
# 12      1.0      True   01 4, 2013  A1G3S57JGZNPCL  B00007GDFV
# 13      1.0      True  07 30, 2012   AGBL3TTP6GV4X  B00007GDFV
# ...

# %%
print(df.columns)
# Out:
# Index(['overall', 'verified', 'reviewTime', 'reviewerID', 'asin',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'style', 'image'],
#       dtype='object')
